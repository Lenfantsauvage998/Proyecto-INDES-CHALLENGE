# %% [markdown]
# # Simple EDA

# %%
## Start coding here ! 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_excel("PREGRADO_CONSOLIDADO_2016_2_2026_1.xlsx")

df
# Out:
#        Grupo Académico Descripción  ID Curso Catálogo       Nombre del curso  \
# 0                    2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 1                    2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 2                    2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 3                    2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 4                    2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# ...                ...         ...       ...      ...                    ...
# 30545                2  INGENIERIA    675358  8026111     PENSAMIENTO LÓGICO
# 30546                2  INGENIERIA    675358  8026111     PENSAMIENTO LÓGICO
# 30547                2  INGENIERIA    675358  8026111     PENSAMIENTO LÓGICO
# 30548                2  INGENIERIA    675359  8026121  LAB FENÓMENOS FÍSICOS
# 30549                2  INGENIERIA    675359  8026121  LAB FENÓMENOS FÍSICOS
#
#       Componente Componente Descripción         Día   F Inicial Fecha Final  \
# 0            LEC                  Clase      Martes  12/07/2016  25/11/2016
# 1            LEC                  Clase      Martes  12/07/2016  25/11/2016
# 2            LEC                  Clase      Martes  12/07/2016  25/11/2016
# 3            LEC                  Clase      Martes  12/07/2016  25/11/2016
# 4            LEC                  Clase      Martes  12/07/2016  25/11/2016
# ...          ...                    ...         ...         ...         ...
# 30545        LEC                  Clase   Miercoles  26/01/2026  02/06/2026
# 30546        LEC                  Clase      Jueves  26/01/2026  02/06/2026
# 30547        LEC                  Clase     Viernes  26/01/2026  02/06/2026
# 30548        LEC                  Clase       Lunes  26/01/2026  02/06/2026
# 30549        LEC                  Clase       Lunes  26/01/2026  02/06/2026
#
#        ...  Tipo Evento Tipo Reunión Descr Tipo Reunión ID Sección Combinada  \
# 0      ...         CRSE         CRSE              Curso                  NaN
# 1      ...         CRSE         CRSE              Curso                  NaN
# 2      ...         CRSE         CRSE              Curso                  NaN
# 3      ...         CRSE         CRSE              Curso                  NaN
# 4      ...         CRSE         CRSE              Curso                  NaN
# ...    ...          ...          ...                ...                  ...
# 30545  ...         CRSE         CRSE              Curso               5134.0
# 30546  ...         CRSE         CRSE              Curso               5016.0
# 30547  ...         CRSE         CRSE              Curso               5017.0
# 30548  ...         CRSE         CRSE              Curso                  NaN
# 30549  ...         CRSE         CRSE              Curso                  NaN
#
#       Modo Enseñanza  Descripción Modo Enseñanza  Clase Principal  Tot Inscr  \
# 0                 PR                  PRESENCIAL                1          0
# 1                 PR                  PRESENCIAL                1          0
# 2                 PR                  PRESENCIAL                1          0
# 3                 PR                  PRESENCIAL                1          0
# 4                 PR                  PRESENCIAL                1          0
# ...              ...                         ...              ...        ...
# 30545             PR                  PRESENCIAL                0         27
# 30546             PR                  PRESENCIAL                0         29
# 30547             PR                  PRESENCIAL                0         25
# 30548             PR                  PRESENCIAL                1          0
# 30549             PR                  PRESENCIAL                1          0
#
#        F Reunión    Descripción.2
# 0     2016-10-11   DOCENTE PLANTA
# 1     2016-10-11   DOCENTE PLANTA
# 2     2016-10-11   DOCENTE PLANTA
# 3     2016-10-11   DOCENTE PLANTA
# 4     2016-10-11   DOCENTE PLANTA
# ...          ...              ...
# 30545 2026-01-28   DOCENTE PLANTA
# 30546 2026-01-29  DOCENTE CATEDRA
# 30547 2026-01-30  DOCENTE CATEDRA
# 30548 2026-01-26  DOCENTE CATEDRA
# 30549 2026-01-26   DOCENTE PLANTA
#
# [30550 rows x 54 columns]

# %%
df.head()
# Out:
#    Grupo Académico Descripción  ID Curso Catálogo       Nombre del curso  \
# 0                2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 1                2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 2                2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 3                2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
# 4                2  INGENIERIA       129    12939  SEMINARIO DE PRACTICA
#
#   Componente Componente Descripción      Día   F Inicial Fecha Final  ...  \
# 0        LEC                  Clase   Martes  12/07/2016  25/11/2016  ...
# 1        LEC                  Clase   Martes  12/07/2016  25/11/2016  ...
# 2        LEC                  Clase   Martes  12/07/2016  25/11/2016  ...
# 3        LEC                  Clase   Martes  12/07/2016  25/11/2016  ...
# 4        LEC                  Clase   Martes  12/07/2016  25/11/2016  ...
#
#    Tipo Evento Tipo Reunión Descr Tipo Reunión ID Sección Combinada  \
# 0         CRSE         CRSE              Curso                  NaN
# 1         CRSE         CRSE              Curso                  NaN
# 2         CRSE         CRSE              Curso                  NaN
# 3         CRSE         CRSE              Curso                  NaN
# 4         CRSE         CRSE              Curso                  NaN
#
#   Modo Enseñanza  Descripción Modo Enseñanza  Clase Principal  Tot Inscr  \
# 0             PR                  PRESENCIAL                1          0
# 1             PR                  PRESENCIAL                1          0
# 2             PR                  PRESENCIAL                1          0
# 3             PR                  PRESENCIAL                1          0
# 4             PR                  PRESENCIAL                1          0
#
#    F Reunión   Descripción.2
# 0 2016-10-11  DOCENTE PLANTA
# 1 2016-10-11  DOCENTE PLANTA
# 2 2016-10-11  DOCENTE PLANTA
# 3 2016-10-11  DOCENTE PLANTA
# 4 2016-10-11  DOCENTE PLANTA
#
# [5 rows x 54 columns]

# %%
df.shape
# Out:
# (30550, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30550 entries, 0 to 30549
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Grupo Académico             30550 non-null  int64
#  1   Descripción                 30550 non-null  object
#  2   ID Curso                    30550 non-null  int64
#  3   Catálogo                    30549 non-null  object
#  4   Nombre del curso            30550 non-null  object
#  5   Componente                  30550 non-null  object
#  6   Componente Descripción      30550 non-null  object
#  7   Día                         30550 non-null  object
#  8   F Inicial                   30550 non-null  object
#  9   Fecha Final                 30550 non-null  object
#  10  Nº Clase                    30550 non-null  int64
#  11  Hora Inicio                 30550 non-null  object
#  12  Hora Final                  30550 non-null  object
#  13  ID Instalación              30423 non-null  object
#  14  ID Instalación descripción  30423 non-null  object
#  15  Capacidad Aula              30550 non-null  int64
#  16  Capacidad Inscripción       30550 non-null  int64
#  17  Total Inscritos             30550 non-null  int64
#  18  Ciclo Lectivo               30550 non-null  object
#  19  Id profesor                 30509 non-null  float64
#  20  Numero documento docente    30500 non-null  object
#  21  Nombre profesor             30516 non-null  object
#  22  Teléfono profesor           30134 non-null  object
#  23  Tipo dedicación             30152 non-null  object
#  24  Descripción dedicación      30152 non-null  object
#  25  Sesión                      30550 non-null  object
#  26  Sección Clase               30550 non-null  object
#  27  Materia                     30550 non-null  object
#  28  Descripción Materia         30550 non-null  object
#  29  Org Acad                    30550 non-null  object
#  30  Descripción.1               30550 non-null  object
#  31  Departamento                26916 non-null  float64
#  32  Correo-E Preferido          30382 non-null  object
#  33  Correo-E Personal           29321 non-null  object
#  34  Telef. Preferido            30134 non-null  object
#  35  Telef. Personal             29616 non-null  object
#  36  Rol Profesor                30544 non-null  object
#  37  Descr Rol                   30544 non-null  object
#  38  Impr Prfs Pr                30544 non-null  object
#  39  Descripción Impr Prfs Pr    30544 non-null  object
#  40  Acceso                      30205 non-null  object
#  41  Descr Acceso                30205 non-null  object
#  42  ID Evento                   30492 non-null  float64
#  43  Descripción Evento          30492 non-null  object
#  44  Tipo Evento                 30492 non-null  object
#  45  Tipo Reunión                30426 non-null  object
#  46  Descr Tipo Reunión          30426 non-null  object
#  47  ID Sección Combinada        5040 non-null   float64
#  48  Modo Enseñanza              30550 non-null  object
#  49  Descripción Modo Enseñanza  28949 non-null  object
#  50  Clase Principal             30550 non-null  int64
#  51  Tot Inscr                   30550 non-null  int64
#  52  F Reunión                   30426 non-null  datetime64[ns]
#  53  Descripción.2               30356 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(8), object(41)
# memory usage: 12.6+ MB

# %%
df.columns
# Out:
# Index(['Grupo Académico', 'Descripción', 'ID Curso', 'Catálogo',
#        'Nombre del curso', 'Componente', 'Componente Descripción', 'Día',
#        'F Inicial', 'Fecha Final', 'Nº Clase', 'Hora Inicio', 'Hora Final',
#        'ID Instalación', 'ID Instalación descripción', 'Capacidad Aula',
#        'Capacidad Inscripción', 'Total Inscritos', 'Ciclo Lectivo',
#        'Id profesor', 'Numero documento docente', 'Nombre profesor',
#        'Teléfono profesor', 'Tipo dedicación', 'Descripción dedicación',
#        'Sesión', 'Sección Clase', 'Materia', 'Descripción Materia', 'Org Acad',
#        'Descripción.1', 'Departamento', 'Correo-E Preferido',
#        'Correo-E Personal', 'Telef. Preferido', 'Telef. Personal',
#        'Rol Profesor', 'Descr Rol', 'Impr Prfs Pr', 'Descripción Impr Prfs Pr',
#        'Acceso', 'Descr Acceso', 'ID Evento', 'Descripción Evento',
#        'Tipo Evento', 'Tipo Reunión', 'Descr Tipo Reunión',
#        'ID Sección Combinada', 'Modo Enseñanza', 'Descripción Modo Enseñanza',
#        'Clase Principal', 'Tot Inscr', 'F Reunión', 'Descripción.2'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Grupo Académico                   0
# Descripción                       0
# ID Curso                          0
# Catálogo                          1
# Nombre del curso                  0
# Componente                        0
# Componente Descripción            0
# Día                               0
# F Inicial                         0
# Fecha Final                       0
# Nº Clase                          0
# Hora Inicio                       0
# Hora Final                        0
# ID Instalación                  127
# ID Instalación descripción      127
# Capacidad Aula                    0
# Capacidad Inscripción             0
# Total Inscritos                   0
# Ciclo Lectivo                     0
# Id profesor                      41
# Numero documento docente         50
# Nombre profesor                  34
# Teléfono profesor               416
# Tipo dedicación                 398
# Descripción dedicación          398
# Sesión                            0
# Sección Clase                     0
# Materia                           0
# Descripción Materia               0
# Org Acad                          0
# Descripción.1                     0
# Departamento                   3634
# Correo-E Preferido              168
# Correo-E Personal              1229
# Telef. Preferido                416
# Telef. Personal                 934
# Rol Profesor                      6
# Descr Rol                         6
# Impr Prfs Pr                      6
# Descripción Impr Prfs Pr          6
# Acceso                          345
# Descr Acceso                    345
# ID Evento                        58
# Descripción Evento               58
# Tipo Evento                      58
# Tipo Reunión                    124
# Descr Tipo Reunión              124
# ID Sección Combinada          25510
# Modo Enseñanza                    0
# Descripción Modo Enseñanza     1601
# Clase Principal                   0
# Tot Inscr                         0
# F Reunión                       124
# Descripción.2                   194
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(37)

# %%
# Basic EDA summary
pd.options.display.max_columns = 50
print("Shape:", df.shape)
print("\nMissing values by column")
print(df.isnull().sum().sort_values(ascending=False).head(20))
print("\nDuplicate rows:", df.duplicated().sum())

print("\nNumeric summary")
display(df.describe(include=[np.number]).T)

print("\nCategorical summary")
display(df.describe(include=["object", "category"]).T)
# Out:
# Shape: (30550, 54)
#
# Missing values by column
# ID Sección Combinada          25510
# Departamento                   3634
# Descripción Modo Enseñanza     1601
# Correo-E Personal              1229
# Telef. Personal                 934
# Teléfono profesor               416
# Telef. Preferido                416
# Tipo dedicación                 398
# Descripción dedicación          398
# Descr Acceso                    345
# Acceso                          345
# Descripción.2                   194
# Correo-E Preferido              168
# ID Instalación descripción      127
# ID Instalación                  127
# Tipo Reunión                    124
# F Reunión                       124
# Descr Tipo Reunión              124
# Descripción Evento               58
# Tipo Evento                      58
# dtype: int64
#
# Duplicate rows: 37
#
# Numeric summary
#                          count           mean            std      min  \
# Grupo Académico        30550.0       2.002095       0.141060      1.0
# ID Curso               30550.0  119393.840000  242372.734026    129.0
# Nº Clase               30550.0    3774.699902    1873.038693   1165.0
# Capacidad Aula         30550.0      98.077905     548.796577      0.0
# Capacidad Inscripción  30550.0      25.642782       8.613651      0.0
# Total Inscritos        30550.0      20.631915       9.109796      1.0
# Id profesor            30509.0   85175.076502  100505.780094     39.0
# Departamento           26916.0    1179.856108     218.128345    326.0
# ID Evento              30492.0   97313.303129   64319.620370  27955.0
# ID Sección Combinada    5040.0     481.873611    1164.067829      1.0
# Clase Principal        30550.0       0.896661       0.304406      0.0
# Tot Inscr              30550.0       4.160753      10.116707      0.0
#
#                            25%      50%       75%       max
# Grupo Académico            2.0      2.0       2.0       8.0
# ID Curso               13393.0  13415.0   13897.0  675360.0
# Nº Clase                2262.0   3072.0    4886.0   10510.0
# Capacidad Aula            26.0     32.0      36.0    5000.0
# Capacidad Inscripción     22.0     26.0      30.0     400.0
# Total Inscritos           15.0     22.0      27.0      84.0
# Id profesor            10278.0  14342.0  166493.0  396001.0
# Departamento            1219.0   1221.0    1222.0    1367.0
# ID Evento              47831.0  80376.0  121521.0  301356.0
# ID Sección Combinada     150.0    216.0     295.0    6810.0
# Clase Principal            1.0      1.0       1.0       1.0
# Tot Inscr                  0.0      0.0       0.0      87.0
# Categorical summary
#                             count unique                             top  \
# Descripción                 30550      3                      INGENIERIA
# Catálogo                    30549    483                           21101
# Nombre del curso            30550    461             CALCULO DIFERENCIAL
# Componente                  30550      3                             LEC
# Componente Descripción      30550      3                           Clase
# Día                         30550     13                           Lunes
# F Inicial                   30550    143                      23/01/2017
# Fecha Final                 30550    165                      30/05/2018
# Hora Inicio                 30550     19                        09:00:AM
# Hora Final                  30550     19                        11:00:AM
# ID Instalación              30423    241                       B203-CAMP
# ID Instalación descripción  30423    258       LABORATORIO DE SIMULACION
# Ciclo Lectivo               30550     20                  PERIODO 2017-1
# Numero documento docente    30500    533                      1013595874
# Nombre profesor             30516    538        MOJICA MACIAS JUAN PABLO
# Teléfono profesor           30134    557                    305/815-0623
# Tipo dedicación             30152      4                               J
# Descripción dedicación      30152      4                      Parcial 45
# Sesión                      30550      1          Sesión Curso Ordinaria
# Sección Clase               30550     92                               1
# Materia                     30550     16                        MATFISEI
# Descripción Materia         30550     16           MATEM. FISICA Y ESTAD
# Org Acad                    30550     16                        MATFISEI
# Descripción.1               30550     16     MATEM. FISICA Y ESTAD. ING.
# Correo-E Preferido          30382    626    wbeimarvema@unisabana.edu.co
# Correo-E Personal           29321    601  SANDRA.MOLINA@UNISABANA.EDU.CO
# Telef. Preferido            30134    557                    305/815-0623
# Telef. Personal             29616    547                    305/815-0623
# Rol Profesor                30544      3                              PI
# Descr Rol                   30544      3                Profesor Titular
# Impr Prfs Pr                30544      2                               Y
# Descripción Impr Prfs Pr    30544      2                              Sí
# Acceso                      30205      3                               P
# Descr Acceso                30205      3                    Contabilizar
# Descripción Evento          30492    464             CALCULO DIFERENCIAL
# Tipo Evento                 30492      4                            CRSE
# Tipo Reunión                30426      1                            CRSE
# Descr Tipo Reunión          30426      1                           Curso
# Modo Enseñanza              30550      3                              PR
# Descripción Modo Enseñanza  28949      2                      PRESENCIAL
# Descripción.2               30356      3                 DOCENTE CATEDRA
#
#                              freq
# Descripción                 30502
# Catálogo                     1848
# Nombre del curso             1848
# Componente                  28458
# Componente Descripción      28458
# Día                          6800
# F Inicial                    2100
# Fecha Final                  2049
# Hora Inicio                  3302
# Hora Final                   3205
# ID Instalación                836
# ID Instalación descripción    836
# Ciclo Lectivo                2123
# Numero documento docente      337
# Nombre profesor               337
# Teléfono profesor             337
# Tipo dedicación             17711
# Descripción dedicación      17711
# Sesión                      30550
# Sección Clase                9494
# Materia                      9967
# Descripción Materia          9967
# Org Acad                     9967
# Descripción.1                9967
# Correo-E Preferido            328
# Correo-E Personal             328
# Telef. Preferido              337
# Telef. Personal               337
# Rol Profesor                30035
# Descr Rol                   30035
# Impr Prfs Pr                21672
# Descripción Impr Prfs Pr    21672
# Acceso                      30153
# Descr Acceso                30153
# Descripción Evento           1853
# Tipo Evento                 30475
# Tipo Reunión                30426
# Descr Tipo Reunión          30426
# Modo Enseñanza              28928
# Descripción Modo Enseñanza  28928
# Descripción.2               17606

# %%
# Visual inspection
plt.figure(figsize=(10, 4))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("Missing values map")
plt.show()

numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
if len(numeric_cols) > 1:
    plt.figure(figsize=(10, 8))
    sns.heatmap(df[numeric_cols].corr(), annot=True, fmt=".2f", cmap="coolwarm", center=0)
    plt.title("Numeric correlation matrix")
    plt.show()

for col in numeric_cols[:4]:
    plt.figure(figsize=(6, 3))
    sns.histplot(df[col].dropna(), kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()
